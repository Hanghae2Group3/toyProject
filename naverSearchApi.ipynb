# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

import ssl
ssl._create_default_https_context = ssl._create_unverified_context
# 임시 ssl 솔루션

client_id = "UGNq9ui5q3eO__Uum_AA"
client_secret = "xDhY4nbmQb"

query = urllib.parse.quote(input("검색어: "))
idx = 0
display = 100
start = 1
end = 1000
book_df = pd.DataFrame(columns=("Title", "link", "Image", "Author", "Price", "Discount", "Publisher", "ISBN", "Description", "Publication Date"))

for start_index in range(start, end, display):
    # 아래는 json 결과
    url = f'https://openapi.naver.com/v1/search/book.json?query={query}&display={display}&start={start_index}'
    # url = "https://openapi.naver.com/v1/search/book.json?query=" + query \
        # + "&display=" + str(display) \
            # + "&start=" + str(start_index)

    # url = "https://openapi.naver.com/v1/search/book.xml?d_titl=" + d_titl # xml 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)

    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            image = items[item_index]['image']
            author = items[item_index]['author']
            price = items[item_index]['price']
            discount = items[item_index]['discount']
            publisher = items[item_index]['publisher']
            isbn = items[item_index]['isbn']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pubdate = items[item_index]['pubdate']
            book_df.loc[idx] = [title, link, image, author, price, discount, publisher, isbn, description, pubdate]
            idx += 1
    else:
        print("Error Code:" + rescode)

book_df
# Out:
#                                    Title  \
# 0     가고 싶다, 모스크바 (디테일이 살아 있는 색다른 지식 여행)
# 1        가고 싶다, 빈 (디테일이 살아 있는 색다른 지식 여행)
# 2                        가고 싶다, 상트페테르부르크
# 3      가고 싶다, 피렌체 (디테일이 살아 있는 색다른 지식 여행)
# 4    가고 싶다, 바르셀로나 (디테일이 살아 있는 색다른 지식 여행)
# ..                                   ...
# 822                            아버지의 병상일기
# 823                             매화가 만발할때
# 824                              그날의 소금밭
# 825                            돌확 속의 지구본
# 826         고뇌하는 영혼 (한 철학자가 걸어온 인생탐구의 길)
#
#                                                   link  \
# 0    http://book.naver.com/bookdb/book_detail.php?b...
# 1    http://book.naver.com/bookdb/book_detail.php?b...
# 2    http://book.naver.com/bookdb/book_detail.php?b...
# 3    http://book.naver.com/bookdb/book_detail.php?b...
# 4    http://book.naver.com/bookdb/book_detail.php?b...
# ..                                                 ...
# 822  http://book.naver.com/bookdb/book_detail.php?b...
# 823  http://book.naver.com/bookdb/book_detail.php?b...
# 824  http://book.naver.com/bookdb/book_detail.php?b...
# 825  http://book.naver.com/bookdb/book_detail.php?b...
# 826  http://book.naver.com/bookdb/book_detail.php?b...
#
#                                                  Image Author  Price Discount  \
# 0    https://bookthumb-phinf.pstatic.net/cover/137/...    신양란  17500    15750
# 1    https://bookthumb-phinf.pstatic.net/cover/147/...    신양란  17500    15750
# 2    https://bookthumb-phinf.pstatic.net/cover/119/...    신양란  17000    15300
# 3    https://bookthumb-phinf.pstatic.net/cover/103/...    신양란  17500    15750
# 4    https://bookthumb-phinf.pstatic.net/cover/078/...    신양란  17000    15300
# ..                                                 ...    ...    ...      ...
# 822  https://bookthumb-phinf.pstatic.net/cover/069/...    임현덕   4500
# 823  https://bookthumb-phinf.pstatic.net/cover/098/...    장현경   5000
# 824  https://bookthumb-phinf.pstatic.net/cover/098/...    김태희   5000
# 825  https://bookthumb-phinf.pstatic.net/cover/097/...    이아영   5000
# 826                                                       최순남  12000
#
#     Publisher                      ISBN  \
# 0          북핀  1187616419 9791187616412
# 1        지혜정원  1187616621 9791187616627
# 2          북핀  1187616125 9791187616122
# 3        지혜정원  1187163015 9791187163015
# 4        지혜정원  8994886540 9788994886541
# ..        ...                       ...
# 822   도서출판글나눔  8997869027 4808997869022
# 823       타임비  8967884222 9788967884222
# 824       타임비  8967883927 9788967883928
# 825    한국문학방송  115513530X 9791155135303
# 826        북랩  1159874492 9791159874499
#
#                                            Description Publication Date
# 0    모스크바의 모든 문화와 역사를 꼼꼼하게 파헤친 지식 여행 가이드!\n우리에게는 아직...         20180710
# 1    빈의 문화와 역사를 꼼꼼하게 파헤친 지식 여행 가이드!\n오스트리아 빈에서 꼭 가봐...         20190425
# 2    『가고 싶다, 상트페테르부르크』는 서유럽의 문물을 적극적으로 받아들이며 수준 높은 ...         20170420
# 3    [가고 싶다, 피렌체]는 아담하고 품격 있는 명품 도시 피렌체를 여행할 많은 여행자...         20160331
# 4    바르셀로나에서 꼭 가봐야 할 장소를 꼼꼼하게 파헤친 색다른 지식 가이드. 바르셀로나...         20140725
# ..                                                 ...              ...
# 822  아버지의 죽음을 맨 눈으로 지켜보며 꺼져가는 아버지의 숨을 지켜가고 있는 그의 모습...         20120718
# 823  시집을 펴내며\n  자연을 좋아하는 나는 바쁜 가운데 사업상 목적지 또는 여행의 진...         20141201
# 824  빗발 김태희 씨는 시인이다. 그냥 시인이 아니라 불타는 시인이다. 눈이 불타고 심장...         20141006
# 825  종교 이상의 힘을 가지고 우리 생활의 근저를 감싸고 있는 아우라라고 해도 과인이 아...         20120830
# 826  저자는 종교와 철학을 뛰어넘어 인간의 고뇌에 대해 탐구해왔다. 기독교임에도 불구하고...         20170222
#
# [827 rows x 10 columns]
